# %% [markdown]
# # Feature Exploration Notebook
#
# This notebook walks through a workflow for exploring SAE features:
# 1. Environment & imports
# 2. Loading models and datasets
# 3. Selecting features of interest
# 4. Analyzing activations
# 5. Visualizing results
# 6. Inspecting token-level context

# %% [markdown]
# # Feature exploration

# %% [markdown]
# ## 1. Set up

# %%
import torch
import sys
from pathlib import Path
from tqdm import tqdm
import heapq
import json

module_path = Path("..").resolve()
sys.path.append(str(module_path))

from music_interpret.modeling.sae import SparseAutoencoder
from music_interpret.activations.dataset import ActivationDataset
from music_interpret.model_adapters.mmt_adapter import MMTAdapter

# %% [markdown]
# ## 2. Load sae and dataset

# %% [markdown]
# ### Set paths to resources that are to be explored
# - ckpt_path - path to the sae checkpoint
# - activ_root - path to shard*.npy files containing activations
# - meta_root - path to shard*.npy files that allow to tranlate activations to music tokens

# %%
ckpt_path = Path("/home/albert-torzewski/PycharmProjects/Start/reports/sanity/diff_ini/sae_ckpt_001.pt")
activ_root = Path("/home/albert-torzewski/PycharmProjects/Start/data/activations/lmd_ape_residual/layer_007/processed") 
meta_root  = Path("/home/albert-torzewski/PycharmProjects/Start/data/activations/lmd_ape_residual/layer_007/meta")

# %% [markdown]
# ### Load SAE checkpoint

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

ckpt = torch.load(ckpt_path, map_location=DEVICE)

sae = SparseAutoencoder(
    input_dim=ckpt["input_dim"],
    latent_dim=ckpt["latent_dim"],
    normalize_decoder=True,
).to(DEVICE)

sae.load_state_dict(ckpt["model_state"])
sae.eval()
# Out:
# SparseAutoencoder(
#   (encoder): Linear(in_features=512, out_features=2048, bias=True)
#   (decoder): Linear(in_features=2048, out_features=512, bias=False)
#   (activation): ReLU()
# )

# %% [markdown]
# ### Load activation dataset

# %%
dataset = ActivationDataset(
    activ_root=activ_root,
    meta_root=meta_root,
)

loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=4096,
    num_workers=4,
)

# %% [markdown]
# ## 3. Feature categorisation based on firing rates

# %%
latent_dim = sae.latent_dim

fire_counts = torch.zeros(latent_dim, dtype=torch.long)
total_tokens = 0

with torch.no_grad():
    for batch in loader:
        x = batch["activations"].to(DEVICE)
        z = sae.encode(x)
        fire_mask = z > 0
        fire_counts += fire_mask.sum(dim=0).cpu()
        total_tokens += z.size(0)

freqs = fire_counts.float() / total_tokens

# %%
print("Total tokens processed:", total_tokens)
print("Num features:", latent_dim)
print("Dead features:", (freqs == 0).sum().item())
print("Overactive features (>10%):", (freqs > 0.1).sum().item())

candidates = torch.where((freqs > 1e-4) & (freqs < 5e-2))[0]

print("First 20 candidate features:", candidates[:20].tolist())
# Out:
# Total tokens processed: 13166182
# Num features: 2048
# Dead features: 102
# Overactive features (>10%): 1051
# First 20 candidate features: [2, 9, 12, 21, 24, 30, 38, 41, 50, 63, 86, 88, 112, 144, 152, 177, 205, 235, 247, 262]

# %% [markdown]
# ### Choose latent to inspect
# - feature_pos - index number of latnet dictiornary param to inspect
# - examples_to_display - number of best 'k' tokens to save for later visualisation

# %%
feature_pos = 112
examples_to_display = 100

# %% [markdown]
# ### Select top k most activating tokens

# %%
topk = []

with torch.no_grad():
    for batch in tqdm(loader, desc=f"Collecting top activations for feature {feature_pos}"):
        x = batch["activations"].to(DEVICE)
        z = sae.encode(x)

        vals = z[:, feature_pos].cpu()
        sample_idx = batch.get("sample_idx")
        token_pos  = batch.get("token_pos")

        for i in range(len(vals)):
            v = float(vals[i])
            if v <= 0:
                continue

            item = (
                v,
                int(sample_idx[i]),
                int(token_pos[i]),
            )

            if len(topk) < examples_to_display:
                heapq.heappush(topk, item)
            else:
                if v > topk[0][0]:
                    heapq.heapreplace(topk, item)

topk_sorted = sorted(topk, key=lambda x: -x[0])
# Out:
# Collecting top activations for feature 112: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3215/3215 [01:05<00:00, 49.33it/s]

# %% [markdown]
# ### TopK print

# %%
print("Top 10 activations:")
for r in topk_sorted[:10]:
    print(r)
# Out:
# Top 10 activations:
# (11.125716209411621, 1569, 13)
# (10.652200698852539, 7283, 15)
# (10.577179908752441, 1809, 12)
# (10.44907283782959, 12015, 8)
# (10.295289993286133, 5774, 7)
# (10.030010223388672, 7307, 7)
# (10.018009185791016, 12050, 9)
# (9.991106986999512, 6754, 22)
# (9.952404975891113, 11422, 7)
# (9.88181209564209, 11276, 9)

# %% [markdown]
# ### Save tokens for later use

# %%
out_path = Path(f"feature_{feature_pos}_top{examples_to_display}.json")

records = [
    {
        "activation": v,
        "sample_idx": s,
        "token_pos": p,
    }
    for (v, s, p) in topk_sorted
]

with open(out_path, "w") as f:
    json.dump(records, f, indent=2)

print("Saved to:", out_path)
# Out:
# Saved to: feature_112_top100.json

# %%
print("Top 10 activations:")
for r in records[:10]:
    print(r)
# Out:
# Top 10 activations:
# {'activation': 11.125716209411621, 'sample_idx': 1569, 'token_pos': 13}
# {'activation': 10.652200698852539, 'sample_idx': 7283, 'token_pos': 15}
# {'activation': 10.577179908752441, 'sample_idx': 1809, 'token_pos': 12}
# {'activation': 10.44907283782959, 'sample_idx': 12015, 'token_pos': 8}
# {'activation': 10.295289993286133, 'sample_idx': 5774, 'token_pos': 7}
# {'activation': 10.030010223388672, 'sample_idx': 7307, 'token_pos': 7}
# {'activation': 10.018009185791016, 'sample_idx': 12050, 'token_pos': 9}
# {'activation': 9.991106986999512, 'sample_idx': 6754, 'token_pos': 22}
# {'activation': 9.952404975891113, 'sample_idx': 11422, 'token_pos': 7}
# {'activation': 9.88181209564209, 'sample_idx': 11276, 'token_pos': 9}

# %% [markdown]
# ## 4. Data visualisation

# %% [markdown]
# ### Optional records load

# %%
records_path = "feature_2_top200.json"

with open(records_path) as f:
    records = json.load(f)

# %% [markdown]
# ### Load original dataset and mmt helper

# %%
adapter = MMTAdapter(dataset_name="lmd", data_repr="ape")
mmt_loader = adapter.create_dataloader(batch_size=1, shuffle=False)

data = mmt_loader.dataset

# %% [markdown]
# ### Define helper print functions

# %%
def get_context_tokens(dataset, sample_idx, pos, window=8):
    """
    Returns:
        tokens  : list of encoded tokens
        center  : index of center token in this window
    """
    sample = dataset[sample_idx][0]
    seq = sample["seq"]

    start = max(0, pos - window)
    end   = min(len(seq), pos + window + 1)

    tokens = seq[start:end]
    center = pos - start
    return tokens, center


def print_context(adapter, dataset, sample_idx, pos, window=8):
    tokens, center = get_context_tokens(dataset, sample_idx, pos, window)

    text = adapter.decode_notes(tokens)

    lines = text.splitlines()

    print("=" * 80)
    print(f"sample_idx={sample_idx} pos={pos}")
    print("-" * 80)

    for i, line in enumerate(lines):
        if i == center:
            print(f">>> {line}  <<<")
        else:
            print(f"    {line}")

    print("-" * 80)

# %% [markdown]
# ### Select display options
# - window - how many tokens before and after should be displayed
# - n_show - how many features to print

# %%
window = 4
n_show = 100

# %% [markdown]
# ### Show tokens in text format

# %%
for r in records[:n_show]:
    print_context(
        adapter,
        data,
        sample_idx=r["sample_idx"],
        pos=r["token_pos"],
        window=window,
    )
# Out:
# ================================================================================
# sample_idx=3750 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: organ
#     Instrument: synth-bass
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: synth-drums
#     Start of notes
#     Note: beat=0, position=0, pitch=D#4, duration=1, instrument=lead
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=9113 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: steel-string-guitar
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=11, pitch=E4, duration=72, instrument=strings
#     Note: beat=0, position=11, pitch=G4, duration=72, instrument=strings
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=8045 pos=7
# --------------------------------------------------------------------------------
#     Instrument: nylon-string-guitar
#     Instrument: bass
#     Instrument: electric-bass
#     Instrument: slap-bass
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=2, instrument=piano
#     Note: beat=0, position=0, pitch=F#2, duration=2, instrument=piano
#     Note: beat=1, position=0, pitch=F#2, duration=2, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=10148 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: organ
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: oboe
#     Instrument: lead
#     Instrument: pad
#     Instrument: synth-drums
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5594 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: nylon-string-guitar
#     Instrument: synth-bass
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: flute
#     Instrument: lead
#     Instrument: pad
#     Instrument: synth-drums
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=7554 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: steel-string-guitar
#     Instrument: electric-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: alto-saxophone
#     Instrument: pan-flute
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=2713 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: organ
#     Instrument: electric-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: alto-saxophone
#     Start of notes
#     Note: beat=0, position=0, pitch=G2, duration=24, instrument=piano
#     Note: beat=0, position=0, pitch=G3, duration=3, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=1822 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=A#3, duration=21, instrument=piano
#     Note: beat=0, position=0, pitch=A#4, duration=7, instrument=piano
#     Note: beat=0, position=0, pitch=C#5, duration=6, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=6886 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Instrument: synth-drums
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=4280 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=F4, duration=4, instrument=piano
#     Note: beat=0, position=0, pitch=F4, duration=4, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=8482 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: synth-bass
#     Instrument: strings
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: kalimba
#     Instrument: synth-drums
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5867 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: strings
#     Instrument: horn
# >>> Instrument: synth-brasses  <<<
#     Instrument: english-horn
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=1, instrument=piano
#     Note: beat=1, position=0, pitch=F#2, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5144 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: celesta
#     Instrument: marimba
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: recorder
#     Instrument: melodic-tom
#     Start of notes
#     Note: beat=0, position=0, pitch=C1, duration=3, instrument=melodic-tom
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=12925 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=E1, duration=18, instrument=electric-bass
#     Note: beat=0, position=0, pitch=E1, duration=18, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=13157 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=D#2, duration=18, instrument=pad
#     Note: beat=0, position=0, pitch=D#3, duration=18, instrument=pad
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=9426 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: nylon-string-guitar
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=B1, duration=3, instrument=piano
#     Note: beat=0, position=0, pitch=F#2, duration=3, instrument=piano
#     Note: beat=0, position=0, pitch=F#2, duration=3, instrument=nylon-string-guitar
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=1277 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: electric-bass
#     Instrument: strings
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=6, pitch=A1, duration=30, instrument=piano
#     Note: beat=0, position=7, pitch=A2, duration=7, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=11505 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: slap-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=B1, duration=6, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=759 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: slap-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=G1, duration=6, instrument=slap-bass
#     Note: beat=0, position=0, pitch=C2, duration=3, instrument=piano
#     Note: beat=0, position=0, pitch=F#2, duration=3, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=1396 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: synth-bass
#     Instrument: strings
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=1, pitch=A2, duration=2, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=12234 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: steel-string-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: alto-saxophone
#     Start of notes
#     Note: beat=0, position=0, pitch=C4, duration=1, instrument=piano
#     Note: beat=2, position=6, pitch=C3, duration=4, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=8624 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: steel-string-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=C#4, duration=48, instrument=pad
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=12748 pos=6
# --------------------------------------------------------------------------------
#     Instrument: music-box
#     Instrument: electric-bass
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=E4, duration=12, instrument=synth-brasses
#     Note: beat=0, position=0, pitch=G4, duration=12, instrument=synth-brasses
#     Note: beat=1, position=0, pitch=G4, duration=12, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=610 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: slap-bass
#     Instrument: strings
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=A4, duration=144, instrument=brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=8494 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: steel-string-guitar
#     Instrument: bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: flute
#     Instrument: synth-drums
#     Start of notes
#     Note: beat=0, position=0, pitch=G#2, duration=2, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=9619 pos=7
# --------------------------------------------------------------------------------
#     Instrument: electric-bass
#     Instrument: slap-bass
#     Instrument: strings
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Instrument: synth-drums
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5797 pos=8
# --------------------------------------------------------------------------------
#     Instrument: steel-string-guitar
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: horn
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=E2, duration=48, instrument=organ
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=6657 pos=6
# --------------------------------------------------------------------------------
#     Instrument: electric-piano
#     Instrument: organ
#     Instrument: steel-string-guitar
#     Instrument: synth-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=D2, duration=1, instrument=steel-string-guitar
#     Note: beat=0, position=0, pitch=E2, duration=1, instrument=steel-string-guitar
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=7484 pos=3
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: organ
#     Instrument: steel-string-guitar
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=A4, duration=5, instrument=synth-brasses
#     Note: beat=0, position=6, pitch=A4, duration=2, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=10132 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=3, instrument=piano
#     Note: beat=0, position=0, pitch=C2, duration=3, instrument=synth-bass
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=2093 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=G4, duration=8, instrument=synth-brasses
#     Note: beat=0, position=9, pitch=B4, duration=9, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=692 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: oboe
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=2, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=9311 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: ocarina
#     Instrument: lead
#     Instrument: pad
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=10495 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=3, instrument=piano
#     Note: beat=0, position=0, pitch=A#2, duration=5, instrument=strings
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=10446 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: steel-string-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: flute
#     Start of notes
#     Note: beat=0, position=0, pitch=D3, duration=12, instrument=piano
#     Note: beat=0, position=0, pitch=A3, duration=4, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=797 pos=6
# --------------------------------------------------------------------------------
#     Instrument: celesta
#     Instrument: synth-bass
#     Instrument: strings
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=4, instrument=celesta
#     Note: beat=1, position=0, pitch=F#2, duration=3, instrument=celesta
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=4778 pos=6
# --------------------------------------------------------------------------------
#     Instrument: electric-guitar
#     Instrument: slap-bass
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=1, instrument=organ
#     Note: beat=1, position=0, pitch=F#2, duration=1, instrument=organ
#     Note: beat=2, position=0, pitch=F#2, duration=1, instrument=organ
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=10253 pos=6
# --------------------------------------------------------------------------------
#     Instrument: electric-guitar
#     Instrument: slap-bass
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=1, instrument=organ
#     Note: beat=1, position=0, pitch=F#2, duration=1, instrument=organ
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=7078 pos=7
# --------------------------------------------------------------------------------
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: strings
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=B2, duration=96, instrument=electric-piano
#     Note: beat=0, position=0, pitch=B2, duration=96, instrument=electric-bass
#     Note: beat=0, position=0, pitch=F#3, duration=96, instrument=electric-piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=9078 pos=7
# --------------------------------------------------------------------------------
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: strings
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=B2, duration=96, instrument=electric-piano
#     Note: beat=0, position=0, pitch=B2, duration=96, instrument=electric-bass
#     Note: beat=0, position=0, pitch=F#3, duration=96, instrument=electric-piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=550 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: marimba
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: synth-drums
#     Start of notes
#     Note: beat=0, position=0, pitch=E4, duration=10, instrument=synth-brasses
#     Note: beat=0, position=6, pitch=E4, duration=10, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=12382 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: electric-piano
#     Instrument: organ
#     Instrument: electric-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: synth-drums
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=1, instrument=piano
#     Note: beat=0, position=0, pitch=F#2, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5800 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: slap-bass
#     Instrument: strings
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=A2, duration=2, instrument=slap-bass
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=13057 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: nylon-string-guitar
#     Instrument: electric-guitar
#     Instrument: electric-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=2, instrument=nylon-string-guitar
#     Note: beat=1, position=0, pitch=F#2, duration=2, instrument=nylon-string-guitar
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5882 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: nylon-string-guitar
#     Instrument: steel-string-guitar
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: soprano-saxophone
#     Instrument: bassoon
#     Start of notes
#     Note: beat=0, position=6, pitch=D3, duration=6, instrument=bassoon
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=11497 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-guitar
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: synth-drums
#     Start of notes
#     Note: beat=0, position=0, pitch=C#2, duration=48, instrument=electric-guitar
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=6116 pos=6
# --------------------------------------------------------------------------------
#     Instrument: electric-piano
#     Instrument: organ
#     Instrument: synth-bass
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: alto-saxophone
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=1, instrument=piano
#     Note: beat=0, position=0, pitch=F#2, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=6335 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-guitar
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: tenor-saxophone
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=1, instrument=organ
#     Note: beat=0, position=0, pitch=G#3, duration=1, instrument=organ
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=2394 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: synth-bass
#     Instrument: strings
#     Instrument: synth-strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=C5, duration=12, instrument=synth-strings
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=8780 pos=7
# --------------------------------------------------------------------------------
#     Instrument: celesta
#     Instrument: nylon-string-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=2, instrument=celesta
#     Note: beat=0, position=0, pitch=F#2, duration=2, instrument=celesta
#     Note: beat=0, position=0, pitch=A4, duration=2, instrument=celesta
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=10057 pos=6
# --------------------------------------------------------------------------------
#     Instrument: electric-piano
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: synth-strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: melodic-tom
#     Instrument: synth-drums
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=9332 pos=6
# --------------------------------------------------------------------------------
#     Instrument: nylon-string-guitar
#     Instrument: electric-guitar
#     Instrument: synth-bass
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=F3, duration=2, instrument=piano
#     Note: beat=0, position=3, pitch=F3, duration=2, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=2501 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: synth-bass
#     Instrument: synth-strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=12, instrument=organ
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5991 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: synth-bass
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=G4, duration=3, instrument=synth-brasses
#     Note: beat=1, position=0, pitch=G4, duration=3, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=4537 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: synth-bass
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=G4, duration=3, instrument=synth-brasses
#     Note: beat=1, position=0, pitch=G4, duration=3, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=7786 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: music-box
#     Instrument: synth-bass
#     Instrument: synth-strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=G5, duration=3, instrument=music-box
#     Note: beat=0, position=3, pitch=F5, duration=3, instrument=music-box
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5475 pos=7
# --------------------------------------------------------------------------------
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: synth-bass
#     Instrument: violin
# >>> Instrument: synth-brasses  <<<
#     Instrument: banjo
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=3, instrument=piano
#     Note: beat=0, position=0, pitch=D3, duration=24, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=923 pos=9
# --------------------------------------------------------------------------------
#     Instrument: steel-string-guitar
#     Instrument: bass
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=B1, duration=2, instrument=piano
#     Note: beat=0, position=0, pitch=E2, duration=16, instrument=bass
#     Note: beat=0, position=0, pitch=F#2, duration=2, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5579 pos=8
# --------------------------------------------------------------------------------
#     Instrument: nylon-string-guitar
#     Instrument: steel-string-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: clarinet
#     Instrument: piccolo
#     Instrument: recorder
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=1119 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=6, pitch=A1, duration=3, instrument=electric-bass
#     Note: beat=0, position=6, pitch=E2, duration=1, instrument=organ
#     Note: beat=0, position=9, pitch=G1, duration=3, instrument=electric-bass
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=531 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=6, pitch=D2, duration=3, instrument=organ
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=6103 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=6, pitch=D2, duration=3, instrument=organ
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=1184 pos=5
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=D2, duration=384, instrument=strings
#     Note: beat=0, position=0, pitch=D3, duration=384, instrument=strings
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5192 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: organ
#     Instrument: bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: melodic-tom
#     Start of notes
#     Note: beat=0, position=0, pitch=E2, duration=3, instrument=melodic-tom
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=11017 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: organ
#     Instrument: bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: melodic-tom
#     Start of notes
#     Note: beat=0, position=0, pitch=E2, duration=3, instrument=melodic-tom
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=4869 pos=6
# --------------------------------------------------------------------------------
#     Instrument: nylon-string-guitar
#     Instrument: electric-bass
#     Instrument: strings
#     Instrument: horn
# >>> Instrument: synth-brasses  <<<
#     Instrument: ocarina
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=10, pitch=D3, duration=9, instrument=electric-bass
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=8949 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: synth-bass
#     Instrument: strings
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=1, instrument=piano
#     Note: beat=1, position=0, pitch=F#2, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5591 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: synth-bass
#     Instrument: strings
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: soprano-saxophone
#     Instrument: alto-saxophone
#     Instrument: lead
#     Instrument: synth-drums
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=6263 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: synth-bass
#     Instrument: strings
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=4, pitch=F#2, duration=1, instrument=piano
#     Note: beat=1, position=4, pitch=F#2, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=10304 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: nylon-string-guitar
#     Instrument: synth-bass
#     Instrument: trumpet
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Instrument: shamisen
#     Start of notes
#     Note: beat=0, position=6, pitch=E2, duration=2, instrument=nylon-string-guitar
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=13180 pos=6
# --------------------------------------------------------------------------------
#     Instrument: electric-piano
#     Instrument: nylon-string-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: oboe
#     Start of notes
#     Note: beat=0, position=0, pitch=C1, duration=84, instrument=strings
#     Note: beat=0, position=0, pitch=C2, duration=84, instrument=strings
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=4992 pos=6
# --------------------------------------------------------------------------------
#     Instrument: electric-piano
#     Instrument: nylon-string-guitar
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: oboe
#     Instrument: pad
#     Instrument: kalimba
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=7602 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: voices
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: synth-drums
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=4, instrument=piano
#     Note: beat=1, position=0, pitch=F#2, duration=3, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=810 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: celesta
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=C#4, duration=48, instrument=pad
#     Note: beat=0, position=0, pitch=F#4, duration=48, instrument=pad
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=13162 pos=6
# --------------------------------------------------------------------------------
#     Instrument: music-box
#     Instrument: strings
#     Instrument: voices
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: oboe
#     Instrument: flute
#     Instrument: pad
#     Instrument: synth-drums
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=9990 pos=10
# --------------------------------------------------------------------------------
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: synth-bass
#     Instrument: tuba
# >>> Instrument: synth-brasses  <<<
#     Instrument: flute
#     Instrument: lead
#     Instrument: synth-drums
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=7297 pos=3
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: electric-bass
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=B1, duration=3, instrument=piano
#     Note: beat=0, position=0, pitch=F2, duration=6, instrument=electric-bass
#     Note: beat=0, position=0, pitch=F4, duration=6, instrument=synth-brasses
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=2497 pos=3
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: electric-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: alto-saxophone
#     Instrument: lead
#     Instrument: pad
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=8966 pos=6
# --------------------------------------------------------------------------------
#     Instrument: electric-piano
#     Instrument: slap-bass
#     Instrument: synth-bass
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=A#4, duration=1, instrument=piano
#     Note: beat=2, position=0, pitch=A#4, duration=1, instrument=piano
#     Note: beat=4, position=0, pitch=A#4, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=747 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-guitar
#     Instrument: electric-bass
#     Instrument: violin
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=3, instrument=electric-bass
#     Note: beat=0, position=3, pitch=D2, duration=3, instrument=electric-bass
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=6645 pos=6
# --------------------------------------------------------------------------------
#     Instrument: music-box
#     Instrument: electric-bass
#     Instrument: synth-bass
#     Instrument: synth-strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=G1, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=1304 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: nylon-string-guitar
#     Instrument: synth-bass
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=2, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=2594 pos=6
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: strings
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: alto-saxophone
#     Instrument: lead
#     Instrument: pad
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=9880 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: electric-piano
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=F#3, duration=36, instrument=electric-piano
#     Note: beat=0, position=0, pitch=C#4, duration=6, instrument=electric-piano
#     Note: beat=0, position=0, pitch=G#4, duration=5, instrument=electric-piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=4847 pos=8
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: steel-string-guitar
#     Instrument: bass
#     Instrument: synth-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: tenor-saxophone
#     Instrument: pan-flute
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=10683 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: organ
#     Instrument: electric-guitar
#     Instrument: synth-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=6, pitch=E3, duration=6, instrument=lead
#     Note: beat=1, position=0, pitch=E4, duration=6, instrument=lead
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=12738 pos=5
# --------------------------------------------------------------------------------
#     Instrument: electric-piano
#     Instrument: steel-string-guitar
#     Instrument: synth-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Instrument: pad
#     Start of notes
#     Note: beat=0, position=0, pitch=F#3, duration=48, instrument=strings
#     Note: beat=0, position=0, pitch=A#3, duration=1, instrument=pad
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=181 pos=8
# --------------------------------------------------------------------------------
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: synth-strings
#     Instrument: voices
# >>> Instrument: synth-brasses  <<<
#     Instrument: lead
#     Instrument: synth-drums
#     Start of notes
#     Note: beat=0, position=0, pitch=F#2, duration=2, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5170 pos=7
# --------------------------------------------------------------------------------
#     Instrument: electric-bass
#     Instrument: strings
#     Instrument: voices
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: tenor-saxophone
#     Instrument: flute
#     Instrument: ocarina
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=10877 pos=7
# --------------------------------------------------------------------------------
#     Instrument: electric-bass
#     Instrument: strings
#     Instrument: voices
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: alto-saxophone
#     Instrument: tenor-saxophone
#     Instrument: lead
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=6513 pos=8
# --------------------------------------------------------------------------------
#     Instrument: celesta
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=2, instrument=piano
#     Note: beat=0, position=0, pitch=E2, duration=7, instrument=electric-bass
#     Note: beat=0, position=0, pitch=F#2, duration=2, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=1030 pos=8
# --------------------------------------------------------------------------------
#     Instrument: celesta
#     Instrument: organ
#     Instrument: electric-bass
#     Instrument: strings
# >>> Instrument: synth-brasses  <<<
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=2, instrument=piano
#     Note: beat=0, position=0, pitch=E2, duration=7, instrument=electric-bass
#     Note: beat=0, position=0, pitch=F#2, duration=2, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=8967 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: organ
#     Instrument: electric-guitar
#     Instrument: slap-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: flute
#     Instrument: lead
#     Start of notes
#     Note: beat=0, position=0, pitch=B1, duration=3, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=5484 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: nylon-string-guitar
#     Instrument: electric-guitar
#     Instrument: electric-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: flute
#     Instrument: pad
#     Instrument: banjo
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=8902 pos=5
# --------------------------------------------------------------------------------
#     Instrument: piano
#     Instrument: nylon-string-guitar
#     Instrument: electric-guitar
#     Instrument: electric-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: tenor-saxophone
#     Start of notes
#     Note: beat=0, position=0, pitch=A2, duration=30, instrument=electric-guitar
#     Note: beat=0, position=0, pitch=E3, duration=30, instrument=electric-guitar
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=4541 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: electric-bass
#     Instrument: synth-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: alto-saxophone
#     Start of notes
#     Note: beat=0, position=0, pitch=C2, duration=1, instrument=piano
#     Note: beat=0, position=0, pitch=G#2, duration=1, instrument=piano
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=6031 pos=4
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: electric-bass
#     Instrument: synth-bass
# >>> Instrument: synth-brasses  <<<
#     Instrument: flute
#     Instrument: lead
#     Instrument: synth-drums
#     Start of notes
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=9617 pos=3
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: organ
# >>> Instrument: synth-brasses  <<<
#     Instrument: oboe
#     Start of notes
#     Note: beat=0, position=0, pitch=C4, duration=3, instrument=organ
#     Note: beat=0, position=0, pitch=G4, duration=3, instrument=organ
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=7540 pos=3
# --------------------------------------------------------------------------------
#     Start of song
#     Instrument: piano
#     Instrument: organ
# >>> Instrument: synth-brasses  <<<
#     Instrument: oboe
#     Start of notes
#     Note: beat=0, position=0, pitch=C4, duration=3, instrument=organ
#     Note: beat=0, position=0, pitch=G4, duration=3, instrument=organ
# --------------------------------------------------------------------------------
# ================================================================================
# sample_idx=12950 pos=8
# --------------------------------------------------------------------------------
#     Instrument: steel-string-guitar
#     Instrument: electric-bass
#     Instrument: strings
#     Instrument: brasses
# >>> Instrument: synth-brasses  <<<
#     Instrument: flute
#     Instrument: lead
#     Instrument: synth-drums
#     Start of notes
# --------------------------------------------------------------------------------
